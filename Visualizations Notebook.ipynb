# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
import time as t
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2024-02-19 10:58:44.752151: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv('bike_rides.csv')
df = df[['power','heart-rate']]
df.dropna()
#Comment for commit
# Out:
#        power  heart-rate
# 0      150.0       102.0
# 1      161.0       103.0
# 2      163.0       105.0
# 3      156.0       106.0
# 4      148.0       106.0
# ...      ...         ...
# 38249    0.0       130.0
# 38250    0.0       130.0
# 38251    0.0       129.0
# 38252    0.0       130.0
# 38253    0.0       130.0
#
# [38254 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df['power'], df['heart-rate'], test_size=0.2, random_state=42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# %%
start_time = t.time()
model = Sequential([
    Dense(units=10, activation='relu', input_shape=(1,)),  # Input layer
    Dense(units=10, activation='relu'),  # Hidden layer
    Dense(units=1)  # Output layer, adjust activation
])


model.compile(optimizer=SGD(learning_rate=0.01),
              loss='mean_squared_error',
              metrics=['mean_squared_error'])  # Use 'mean_squared_error' for regression tasks


SGD_history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=32,
                    validation_data=(X_val, y_val))


test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test MSE: {test_accuracy}")
print(f"Time taken: {t.time() - start_time}")
# Out:
# Epoch 1/100
# 718/718 [==============================] - 1s 962us/step - loss: 1093.3771 - mean_squared_error: 1093.3771 - val_loss: 277.4601 - val_mean_squared_error: 277.4601
# Epoch 2/100
# 718/718 [==============================] - 1s 728us/step - loss: 272.9702 - mean_squared_error: 272.9702 - val_loss: 277.7930 - val_mean_squared_error: 277.7930
# Epoch 3/100
# 718/718 [==============================] - 1s 705us/step - loss: 273.1014 - mean_squared_error: 273.1014 - val_loss: 277.7341 - val_mean_squared_error: 277.7341
# Epoch 4/100
# 718/718 [==============================] - 1s 783us/step - loss: 273.0130 - mean_squared_error: 273.0130 - val_loss: 277.4561 - val_mean_squared_error: 277.4561
# Epoch 5/100
# 718/718 [==============================] - 0s 693us/step - loss: 273.0137 - mean_squared_error: 273.0137 - val_loss: 277.6125 - val_mean_squared_error: 277.6125
# Epoch 6/100
# ...

# %%
start_time = t.time()
model = Sequential([
    Dense(units=10, activation='relu', input_shape=(1,)),  # Input layer
    Dense(units=10, activation='relu'),  # Hidden layer
    Dense(units=1)  # Output layer, adjust activation
])


model.compile(optimizer=Adam(learning_rate=0.01),
              loss='mean_squared_error',
              metrics=['mean_squared_error'])  # Use 'mean_squared_error' for regression tasks


Adam_history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=32,
                    validation_data=(X_val, y_val))


test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test MSE: {test_accuracy}")
print(f"Time taken: {t.time() - start_time}")
# Out:
# Epoch 1/100
# 718/718 [==============================] - 1s 931us/step - loss: 3127.8020 - mean_squared_error: 3127.8020 - val_loss: 321.2024 - val_mean_squared_error: 321.2024
# Epoch 2/100
# 718/718 [==============================] - 1s 779us/step - loss: 263.6168 - mean_squared_error: 263.6168 - val_loss: 347.0909 - val_mean_squared_error: 347.0909
# Epoch 3/100
# 718/718 [==============================] - 1s 751us/step - loss: 259.4767 - mean_squared_error: 259.4767 - val_loss: 303.0521 - val_mean_squared_error: 303.0521
# Epoch 4/100
# 718/718 [==============================] - 1s 747us/step - loss: 249.5421 - mean_squared_error: 249.5421 - val_loss: 744.0549 - val_mean_squared_error: 744.0549
# Epoch 5/100
# 718/718 [==============================] - 1s 755us/step - loss: 247.2547 - mean_squared_error: 247.2547 - val_loss: 224.7732 - val_mean_squared_error: 224.7732
# Epoch 6/100
# ...

# %%
start_time = t.time()
model = Sequential([
    Dense(units=10, activation='relu', input_shape=(1,)),  # Input layer
    Dense(units=10, activation='relu'),  # Hidden layer
    Dense(units=1)  # Output layer, adjust activation
])


model.compile(optimizer=RMSprop(learning_rate=0.01),
              loss='mean_squared_error',
              metrics=['mean_squared_error'])  # Use 'mean_squared_error' for regression tasks


RMS_history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=32,
                    validation_data=(X_val, y_val))


test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test MSE: {test_accuracy}")
print(f"Time taken: {t.time() - start_time}")
# Out:
# Epoch 1/100
# 718/718 [==============================] - 1s 841us/step - loss: 2755.7788 - mean_squared_error: 2755.7788 - val_loss: 372.0513 - val_mean_squared_error: 372.0513
# Epoch 2/100
# 718/718 [==============================] - 1s 711us/step - loss: 538.1967 - mean_squared_error: 538.1967 - val_loss: 315.8540 - val_mean_squared_error: 315.8540
# Epoch 3/100
# 718/718 [==============================] - 1s 725us/step - loss: 328.9239 - mean_squared_error: 328.9239 - val_loss: 225.9270 - val_mean_squared_error: 225.9270
# Epoch 4/100
# 718/718 [==============================] - 1s 736us/step - loss: 238.6800 - mean_squared_error: 238.6800 - val_loss: 217.8760 - val_mean_squared_error: 217.8760
# Epoch 5/100
# 718/718 [==============================] - 1s 739us/step - loss: 225.6401 - mean_squared_error: 225.6401 - val_loss: 219.0829 - val_mean_squared_error: 219.0829
# Epoch 6/100
# ...

# %%
import matplotlib.pyplot as plt

# Assuming Adam_history and RMS_history are the History objects from training your models

# Plotting the mean squared error over epochs for the Adam optimizer model


# Plotting the mean squared error over epochs for the RMSprop optimizer model
plt.plot([np.log10(mse) for mse in RMS_history.history['mean_squared_error']], label='RMSprop MSE')
plt.plot([np.log10(mse) for mse in Adam_history.history['mean_squared_error']], label='Adamprop MSE')
plt.plot([np.log10(mse) for mse in SGD_history.history['mean_squared_error']], label='SGDprop MSE')
#Plotting the mean squared error over epochs for the SGD optimizer model
#plt.plot(SGD_history.history['mean_squared_error'], label='SGD MSE')

# Adding labels and legend
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (log-transformed)')
plt.title('Model Mean Squared Error by Epoch')
plt.legend()
plt.ylim(2.3, 2.8)
plt.xlim(0,10)
plt.show()

# %%
Adam_history.history['mean_squared_error']
# Out:
# [3127.802001953125,
#  263.6168212890625,
#  259.4766540527344,
#  249.54212951660156,
#  247.25469970703125,
#  242.7921142578125,
#  241.0210723876953,
#  236.97972106933594,
#  242.61790466308594,
#  239.7040557861328,
#  231.75350952148438,
#  235.411376953125,
#  229.56663513183594,
#  228.68138122558594,
#  222.88604736328125,
#  227.90769958496094,
#  221.34754943847656,
#  224.0604248046875,
#  220.80487060546875,
#  219.67184448242188,
#  219.29014587402344,
#  217.66665649414062,
#  214.77536010742188,
#  216.9738006591797,
#  212.9727325439453,
#  216.4276123046875,
#  217.0409393310547,
#  214.4879150390625,
#  216.4160614013672,
#  214.3707733154297,
#  213.00714111328125,
#  213.837158203125,
#  212.49864196777344,
#  212.56851196289062,
#  210.6158447265625,
#  210.0449676513672,
#  210.59442138671875,
#  209.080322265625,
#  210.00572204589844,
#  210.01109313964844,
#  209.81582641601562,
#  209.43466186523438,
#  209.68942260742188,
#  210.12277221679688,
# ...
